# %%
from  modelclass  import model  
import modelwidget_input as mw 
from modelwidget_input import sumslidewidget, slidewidget, tabwidget

# %%
mport,baseline = model.modelload('model/port',run=1)
# Out:
# Zipped file read:  model\port.pcim

# %%
var_names = mport['new_issue_sh*'].names
def build_sorted_desc_dict(var_names):
    parsed = []

    for v in var_names:
        tail = v.split('__')[1]          # e.g. '10_YEAR_DOM'
        parts = tail.split('_')          # ['10', 'YEAR', 'DOM']

        maturity = int(parts[0])        # numeric for sorting
        currency = parts[2].lower()     # dom or usd

        currency_label = 'domestic' if currency == 'dom' else currency.upper()
        description = f"{maturity} year {currency_label} bond"

        # sort key: domestic first (0), then usd (1), then maturity
        currency_order = 0 if currency == 'dom' else 1

        parsed.append((currency_order, maturity, v, description))

    # Sort by currency first, then maturity
    parsed.sort()

    # Build ordered dict (normal dict preserves order in Python 3.7+)
    return {v: desc for _, _, v, desc in parsed}


sharedict = build_sorted_desc_dict(var_names)

# %%
sharedef = {d: 
            {'var':v,
            'value' : float(baseline.loc[2026,v  ]),
             'min':0,
             'max':100.0 ,'step':5.0
            } for v,d in sharedict.items()}
wshare =mw.sumslidewidget(wsharedef:={'content':sharedef,'maxsum':100.0,'heading':'Issuance policy, shares of each bond'})

# %%
display(wshare.datawidget)
# Out:
# VBox(children=(HBox(children=(Label(value='Issuance policy, shares of each bond', layout=Layout(width='54%')),…

# %%
var_names = mport['interest_rate__? interest_rate__?? interest_rate_???__? interest_rate_???__?? '].names
def build_sorted_desc_dict_implicit_dom(var_names):
    parsed = []

    for v in var_names:
        left, maturity = v.rsplit('__', 1)
        maturity = int(maturity)

        # Currency detection
        if left.endswith('_USD'):
            currency = 'usd'
            currency_label = 'USD'
        else:
            currency = 'dom'
            currency_label = 'domestic'

        description = f"{maturity} year {currency_label} bond interest rate"

        # Sort key: domestic first, then maturity
        currency_order = 0 if currency == 'dom' else 1

        parsed.append((currency_order, maturity, v, description))

    parsed.sort()

    return {v: desc for _, _, v, desc in parsed}


ratedict = build_sorted_desc_dict_implicit_dom(var_names)

# %%
ratedef = {d: 
            {'var':v,
            'value' : float(baseline.loc[2026,v  ]),
             'min':0,
             'max':10.0 ,'step':0.1
            } for v,d in ratedict.items()}
wratedef = {'content':ratedef,'maxsum':100.0,'heading':'Iterest rate'}
wrate =slidewidget( wratedef)
display(wrate.datawidget)
# Out:
# VBox(children=(HBox(children=(Label(value='Iterest rate', layout=Layout(width='54%')), Label(value='Alternativ…

# %%
portdef = ['tab',{'content':[
                              ['Rentestød',            ['slide',{'content':[wratedef]}]],
                              ['Udstedelses strategi' ,['sumslide',{'content':[wsharedef]}]]
                            ]
                            ,
                'tab':True}]


wport=mw. make_widget(portdef)
display(wport.datawidget)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 9
#       1 portdef = ['tab',{'content':[
#       2                               ['Rentestød',            ['slide',{'content':[wratedef]}]],
#       3                               ['Udstedelses strategi' ,['sumslide',{'content':[wsharedef]}]]
#       4                             ]
#       5                             ,
#       6                 'tab':True}]
# ----> 9 wport=mw. make_widget(portdef)
#      10 display(wport.datawidget)
#
# File C:\modelflow2\modelflow\modelwidget_input.py:1311, in make_widget(widgetdef)
#    1307 '''
#    1308 '''
#    1310 widgettype,widgetdict  = widgetdef
# -> 1311 reswidget = globals()[widgettype+'widget'](widgetdict)
#    1312 return reswidget
#
# File <string>:6, in __init__(self, widgetdef, selected_index, tab)
#
# File C:\modelflow2\modelflow\modelwidget_input.py:171, in tabwidget.__post_init__(self)
#     167 self.tabdefheadings = [subtabdef[0] for subtabdef in self.content]
#     169 thiswidget = Tab if self.tab else Accordion
# --> 171 self.datachildren = [globals()[subwidgettype + 'widget'](subwidgetdict)
#     172                      for tabheading, (subwidgettype, subwidgetdict) in self.content]
#     174 self.datawidget = thiswidget([child.datawidget for child in self.datachildren],
#     175                              selected_index=self.selected_index,
#     176                              layout={'height': 'max-content'})
#     178 for i, key in enumerate(self.tabdefheadings):
#
# File <string>:6, in __init__(self, widgetdef, altname, basename)
#
# File C:\modelflow2\modelflow\modelwidget_input.py:303, in slidewidget.__post_init__(self)
#     290 wbas = widgets.Label(value=self.basename, layout={'width': '10%', 'border': "hide"})
#     291 whead = HBox([wexp, walt, wbas])
#     293 self.wset = [widgets.FloatSlider(description=des,
#     294                                  min=cont['min'],
#     295                                  max=cont['max'],
#     296                                  value=cont['value'],
#     297                                  step=cont.get('step', 0.01),
#     298                                  layout={'width': '60%'}, style={'description_width': '40%'},
#     299                                  readout_format=f":>,.{cont.get('dec', 2)}f",
#     300                                  continuous_update=False,
#     301
#     302                                  )
# --> 303              for des, cont in self.content.items()]
#     305 for w in self.wset:
#     306     w.observe(self.set_slide_value, names='value', type='change')
#
# AttributeError: 'list' object has no attribute 'items'

# %%
wport = tabwidget({'content':[
                              ['Rentestød',wrate],
                              ['Udstedelses strategi' ,wshare]
                             ]
                            ,
                'tab':True})


display(wport.datawidget)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 wport = tabwidget({'content':[
#       2                               ['Rentestød',wrate],
#       3                               ['Udstedelses strategi' ,wshare]
#       4                              ]
#       5                             ,
#       6                 'tab':True})
#       9 display(wport.datawidget)
#
# File <string>:6, in __init__(self, widgetdef, selected_index, tab)
#
# File C:\modelflow2\modelflow\modelwidget_input.py:172, in tabwidget.__post_init__(self)
#     167 self.tabdefheadings = [subtabdef[0] for subtabdef in self.content]
#     169 thiswidget = Tab if self.tab else Accordion
#     171 self.datachildren = [globals()[subwidgettype + 'widget'](subwidgetdict)
# --> 172                      for tabheading, (subwidgettype, subwidgetdict) in self.content]
#     174 self.datawidget = thiswidget([child.datawidget for child in self.datachildren],
#     175                              selected_index=self.selected_index,
#     176                              layout={'height': 'max-content'})
#     178 for i, key in enumerate(self.tabdefheadings):
#
# TypeError: cannot unpack non-iterable slidewidget object

# %%
    slidedef =  ['slide', {'heading':'Dette er en prøve', 
                'content' :{'Productivity'    : {'var':'ALFA',             'value': 0.5 ,'min':0.0, 'max':1.0},
                 'DEPRECIATES_RATE' : {'var':'DEPRECIATES_RATE', 'value': 0.05,'min':0.0, 'max':1.0}, 
                 'LABOR_GROWTH'     : {'var':'LABOR_GROWTH',     'value': 0.01,'min':0.0, 'max':1.0},
                 'SAVING_RATIO'     : {'var': 'SAVING_RATIO',    'value': 0.05,'min':0.0, 'max':1.0}
                        }}  ]
    
    radiodef =   ['radio', {'heading':'Dette er en anden prøve', 
                'content' : {'Ib': [['Arbejdskraft','LABOR_GROWTH'],
                       ['Opsparing','SAVING_RATIO'] ],
               'Søren': [['alfa','ALFA'],
                       ['a','A'] ],
               'Marie': [['Hest','HEST'],
                       ['Ko','KO'] ],
               
               }} ]
    
    checkdef =   ['check', {'heading':'Dette er en treidje prøve', 
                'content' :{'Arbejdskraft':['LABOR_GROWTH KO',1],
                           'Opsparing'  :['SAVING_RATIO',0] }}]
    
    alldef = [slidedef] + [radiodef] + [checkdef]
                  
    
    tabdef = ['tab',{'content':[['Den første',['base',{'content':alldef}]],
                                ['Den anden' ,['base',{'content':alldef}]]]
                                ,
                    'tab':False}]
    basedef = ['base',{'content':[slidedef,radiodef]}]
        
    xx =mw. make_widget(tabdef)

# %%
display(xx.datawidget)
# Out:
# Accordion(children=(VBox(children=(VBox(children=(HBox(children=(Label(value='Dette er en prøve', layout=Layou…
